# %%
import pandas as pd
import numpy as np

df = pd.read_csv("loan.csv")
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_13088\1770591969.py:4: DtypeWarning: Columns (46) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("loan.csv")
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# ...

# %%
df.shape
# Out:
# (39717, 110)

# %%
df['issue_d'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 39717 entries, 0 to 39716
# Series name: issue_d
# Non-Null Count  Dtype
# --------------  -----
# 39717 non-null  object
# dtypes: object(1)
# memory usage: 310.4+ KB

# %% [markdown]
# from datetime import datetime
# df['date']= pd.to_datetime(df['issue_d'].dt.date)

# %%
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.559950  6.896893e+04     13.315130
# std        7128.450439    208.877512  6.379377e+04      6.678594
# min           0.000000      6.000000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
df['loan_status'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 39712    False
# 39713    False
# 39714    False
# 39715    False
# 39716    False
# Name: loan_status, Length: 39717, dtype: bool

# %%
loan_status_group = df.groupby('loan_status')

# %%
loan_status_group

# %%
Paid_Off = loan_status_group.get_group("Fully Paid")
Paid_Off
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 5      1075269    1311441       5000         5000           5000.0
# 6      1069639    1304742       7000         7000           7000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 0       36 months   10.65%       162.87     B        B2  ...
# ...

# %%
Defaulter = loan_status_group.get_group('Charged Off')
Defaulter
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 1      1077430    1314167       2500         2500           2500.0
# 8      1071795    1306957       5600         5600           5600.0
# 9      1071570    1306721       5375         5375           5350.0
# 12     1064687    1298717       9000         9000           9000.0
# 14     1069057    1303503      10000        10000          10000.0
# ...        ...        ...        ...          ...              ...
# 39667   118823     118026       2500         2500            675.0
# 39668   118533     117783       2500         2500            825.0
# 39669   118523     118519       6500         6500            225.0
# 39678   113179     113093       1000         1000            950.0
# 39688   111227     111223      20000        20000           2800.0
#
#              term int_rate  installment grade sub_grade  ...  \
# 1       60 months   15.27%        59.83     C        C4  ...
# ...

# %% [markdown]
# Total number of defaulters = 5627

# %%
Defaulter.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  5.627000e+03  5.627000e+03   5627.000000   5627.000000
# mean   6.978440e+05  8.677521e+05  12104.385108  11753.398792
# std    2.163767e+05  2.723270e+05   8085.732038   7760.516335
# min    6.141900e+04  8.035300e+04    900.000000    900.000000
# 25%    5.297245e+05  6.849050e+05   5600.000000   5575.000000
# 50%    6.969370e+05  8.881580e+05  10000.000000  10000.000000
# 75%    8.548760e+05  1.066578e+06  16500.000000  16000.000000
# max    1.077430e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv  installment    annual_inc          dti  delinq_2yrs  \
# count      5627.000000  5627.000000  5.627000e+03  5627.000000  5627.000000
# mean      10864.521324   336.175006  6.242730e+04    14.000624     0.170606
# std        7661.750540   217.051841  4.777601e+04     6.585577     0.534986
# min           0.000000    22.790000  4.080000e+03     0.000000     0.000000
# ...

# %%
Defaulter_group = Defaulter.groupby('purpose').mean() 
Defaulter_group
# Out:
#                                id      member_id     loan_amnt   funded_amnt  \
# purpose
# car                 693159.356250  863942.387500   7264.218750   7202.656250
# credit_card         715177.592251  885843.448339  13014.944649  12546.125461
# debt_consolidation  716512.425009  891527.833755  13517.925551  13130.375858
# educational         428387.482143  510407.250000   7858.928571   7508.482143
# home_improvement    679610.651297  846852.708934  11913.688761  11640.994236
# house               679112.847458  844840.508475  12640.254237  12523.728814
# major_purchase      643930.671171  808595.063063   9135.022523   8885.585586
# medical             701678.500000  873091.358491   8568.396226   8568.396226
# moving              713575.217391  893299.097826   5936.141304   5838.586957
# other               677546.800948  841748.873618   8284.873618   7991.824645
# renewable_energy    688212.421053  872383.315789   8421.052632   8259.210526
# ...

# %%
dg = pd.DataFrame(Defaulter_group, columns=['loan_amnt','total_pymnt'])
dg
# Out:
#                        loan_amnt  total_pymnt
# purpose
# car                  7264.218750  4736.822021
# credit_card         13014.944649  7781.169413
# debt_consolidation  13517.925551  7815.394353
# educational          7858.928571  4536.863600
# home_improvement    11913.688761  6348.843833
# house               12640.254237  7965.438475
# major_purchase       9135.022523  4897.505938
# medical              8568.396226  4468.021509
# moving               5936.141304  2924.423587
# other                8284.873618  4434.816056
# renewable_energy     8421.052632  4948.389474
# small_business      14604.894737  7218.629794
# vacation             5875.943396  3897.929434
# wedding             10786.979167  6077.537500

# %%
from matplotlib.pyplot import figure 
plt.rcParams["figure.figsize"]=(14,8)
dg.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='purpose'>

# %%
Defaulter_group.apply(list)
# Out:
#                                id      member_id     loan_amnt   funded_amnt  \
# purpose
# car                 693159.356250  863942.387500   7264.218750   7202.656250
# credit_card         715177.592251  885843.448339  13014.944649  12546.125461
# debt_consolidation  716512.425009  891527.833755  13517.925551  13130.375858
# educational         428387.482143  510407.250000   7858.928571   7508.482143
# home_improvement    679610.651297  846852.708934  11913.688761  11640.994236
# house               679112.847458  844840.508475  12640.254237  12523.728814
# major_purchase      643930.671171  808595.063063   9135.022523   8885.585586
# medical             701678.500000  873091.358491   8568.396226   8568.396226
# moving              713575.217391  893299.097826   5936.141304   5838.586957
# other               677546.800948  841748.873618   8284.873618   7991.824645
# renewable_energy    688212.421053  872383.315789   8421.052632   8259.210526
# ...

# %%
Still_paying = loan_status_group.get_group('Current')
Still_paying
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 4      1075358    1311748       3000         3000       3000.00000
# 32     1065420    1299514      10000        10000       9975.00000
# 39     1069346    1304237      12500        12500      12475.00000
# 86     1063958    1297940      14000        14000      13975.00000
# 95     1068575    1303001      15300        15300      15275.00000
# ...        ...        ...        ...          ...              ...
# 15972   725556     920821      10400        10400      10400.00000
# 15981   738420     935790       6000         6000       6000.00000
# 16361   733695     930086      19200        19200      18847.76292
# 16609   728422     924106       9350         9350       9350.00000
# 18215   702171     894029       9000         9000       9000.00000
#
#              term int_rate  installment grade sub_grade  ...  \
# 4       60 months   12.69%        67.79     B        B5  ...
# ...

# %%
Still_paying.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  1.140000e+03  1.140000e+03   1140.000000   1140.000000
# mean   9.116569e+05  1.127244e+06  17053.991228  16485.701754
# std    1.046875e+05  1.171559e+05   8651.052316   8183.567669
# min    6.829520e+05  5.230860e+05   1000.000000   1000.000000
# 25%    8.195012e+05  1.024826e+06  12000.000000  11575.000000
# 50%    8.848425e+05  1.099386e+06  15825.000000  15225.000000
# 75%    1.015549e+06  1.242784e+06  23000.000000  21281.250000
# max    1.075358e+06  1.311748e+06  35000.000000  35000.000000
#
#        funded_amnt_inv  installment     annual_inc          dti  delinq_2yrs  \
# count      1140.000000  1140.000000    1140.000000  1140.000000  1140.000000
# mean      16318.265247   395.476061   75430.665105    14.750009     0.141228
# std        8087.613125   204.492991   46775.431597     6.710482     0.476177
# min        1000.000000    21.740000    9960.000000     0.000000     0.000000
# ...

# %% [markdown]
# Customers who are still paying = 1140

# %%
Funded_amount = df['funded_amnt'].sum()
Funded_amount
# Out:
# 434810325

# %% [markdown]
# Total Funded Amount= 434810325

# %%
Payment_amount = df['total_pymnt'].sum()
Payment_amount
# Out:
# 482704393.92338794

# %% [markdown]
# Total payment to bank= 482704393.92338794

# %% [markdown]
# Company's profit:

# %%
Profit = Payment_amount - Funded_amount
Profit
# Out:
# 47894068.923387945

# %% [markdown]
# side by Side Bar Chart to compare loan amount and total_amount of Defaulters:

# %%
plt.rcParams["figure.figsize"]=(12,8)
fig,axes = plt.subplots(1,2)
Defaulter.hist('loan_amnt',label= 'Loan Amount', ax=axes[0],color='green')
Defaulter.hist('total_pymnt',label= 'Total Amount', ax=axes[1])
# Out:
# array([<AxesSubplot:title={'center':'total_pymnt'}>], dtype=object)

# %%
income_df = pd.DataFrame(df, columns=['loan_amnt', 'total_pymnt', 'issue_d' ])
income_df
# Out:
#        loan_amnt   total_pymnt     issue_d
# 0           5000   5863.155187  11-12-2022
# 1           2500   1008.710000  11-12-2022
# 2           2400   3005.666844  11-12-2022
# 3          10000  12231.890000  11-12-2022
# 4           3000   3513.330000  11-12-2022
# ...          ...           ...         ...
# 39712       2500   2822.969293  07-07-2022
# 39713       8500   9913.491822  07-07-2022
# 39714       5000   5272.161128  07-07-2022
# 39715       5000   5174.198551  07-07-2022
# 39716       7500   9195.263334  07-06-2022
#
# [39717 rows x 3 columns]

# %%
income_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   loan_amnt    39717 non-null  int64
#  1   total_pymnt  39717 non-null  float64
#  2   issue_d      39717 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 931.0+ KB

# %% [markdown]
# Type Casting Date from String Format to Date Time Format

# %%
income_df['issue_d']=pd.to_datetime(income_df['issue_d'])

# %%
income_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   loan_amnt    39717 non-null  int64
#  1   total_pymnt  39717 non-null  float64
#  2   issue_d      39717 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 931.0 KB

# %%
import datetime as dt
per = income_df.issue_d.dt.to_period("M") 
income_month = income_df.groupby(per)
income_month

# %%
income_month.describe()
# Out:
#         loan_amnt                                                      \
#             count          mean          std     min     25%      50%
# issue_d
# 2022-07     251.0   8841.733068  6447.772009   500.0  4137.5   6500.0
# 2022-08    1562.0   9212.724072  5774.293733   500.0  5000.0   7500.0
# 2022-09    4716.0   9846.548982  5934.104313  1000.0  5000.0   9000.0
# 2022-10   11532.0  10583.610822  6602.359718  1000.0  5000.0   9600.0
# 2022-11   21656.0  12029.302503  8159.402755  1000.0  6000.0  10000.0
#
#                           total_pymnt                                      \
#              75%      max       count          mean           std     min
# issue_d
# 2022-07  12000.0  25000.0       251.0   8815.504624   6489.989712  520.03
# 2022-08  12000.0  25000.0      1562.0   9004.886587   6247.616938   83.95
# 2022-09  14000.0  25000.0      4716.0  10674.374785   7043.331885    0.00
# 2022-10  15000.0  25000.0     11532.0  11316.396580   7722.488209    0.00
# ...

# %% [markdown]
# Mean monthly Total loan amount and total payment by customers.

# %%
income_month_mean = income_month.mean()
income_month_mean
# Out:
#             loan_amnt   total_pymnt
# issue_d
# 2022-07   8841.733068   8815.504624
# 2022-08   9212.724072   9004.886587
# 2022-09   9846.548982  10674.374785
# 2022-10  10583.610822  11316.396580
# 2022-11  12029.302503  13187.339886

# %% [markdown]
# Graph to demonstrate monthly income.

# %%
income_month_mean.plot()
plt.grid()
